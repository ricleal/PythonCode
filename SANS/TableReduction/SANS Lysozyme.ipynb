# %%
import pandas as pd
from io import StringIO

# %%
data = """SampleChangerPos	SampleName	SampleConcentration	BufferContainer	BufferName	BufferPercentageD2O	Notes
1						Nothing
2			Cell			Just the cell
3			Cell	PEG 400	30	Background
4	lysozyme	3	Cell	PEG 400	30	
5	lysozyme	6	Cell	PEG 400	30	
6	lysozyme	10	Cell	PEG 400	30	
7			Cell	PEG 400	60	Background
8	lysozyme	3	Cell	PEG 400	60	
9	lysozyme	6	Cell	PEG 400	60	
10	lysozyme	10	Cell	PEG 400	60	
11	Thaumatin	5	Cell	PEG 400	60	
12	Thaumatin	10	Cell	PEG 400	60	
13	Thaumatin	15	Cell	PEG 400	60	
14	Thaumatin	20	Cell	PEG 400	10	
15	Thaumatin	25	Cell	PEG 400	10	"""


dataio = StringIO(data)
df = pd.read_csv(dataio, delimiter="\t",  index_col="SampleChangerPos")
df
# Out:
#                  SampleName  SampleConcentration BufferContainer BufferName  \
# SampleChangerPos
# 1                       NaN                  NaN             NaN        NaN
# 2                       NaN                  NaN            Cell        NaN
# 3                       NaN                  NaN            Cell    PEG 400
# 4                  lysozyme                  3.0            Cell    PEG 400
# 5                  lysozyme                  6.0            Cell    PEG 400
# 6                  lysozyme                 10.0            Cell    PEG 400
# 7                       NaN                  NaN            Cell    PEG 400
# 8                  lysozyme                  3.0            Cell    PEG 400
# 9                  lysozyme                  6.0            Cell    PEG 400
# 10                 lysozyme                 10.0            Cell    PEG 400
# 11                Thaumatin                  5.0            Cell    PEG 400
# ...

# %%
#
# How many different buffers?
#
df[["BufferName","BufferPercentageD2O"]].drop_duplicates().dropna()
# Out:
#                  BufferName  BufferPercentageD2O
# SampleChangerPos
# 3                   PEG 400                 30.0
# 7                   PEG 400                 60.0
# 14                  PEG 400                 10.0

# %%
#
# How many different samples?
#
df[["SampleName","SampleConcentration"]].drop_duplicates().dropna()
# Out:
#                  SampleName  SampleConcentration
# SampleChangerPos
# 4                  lysozyme                  3.0
# 5                  lysozyme                  6.0
# 6                  lysozyme                 10.0
# 11                Thaumatin                  5.0
# 12                Thaumatin                 10.0
# 13                Thaumatin                 15.0
# 14                Thaumatin                 20.0
# 15                Thaumatin                 25.0

# %%
#
# How many lysozyme with concentration of 3
#
df[ (df["SampleName"] == "lysozyme") & (df["SampleConcentration"] == 3)]
# Out:
#                  SampleName  SampleConcentration BufferContainer BufferName  \
# SampleChangerPos
# 4                  lysozyme                  3.0            Cell    PEG 400
# 8                  lysozyme                  3.0            Cell    PEG 400
#
#                   BufferPercentageD2O Notes
# SampleChangerPos
# 4                                30.0   NaN
# 8                                60.0   NaN

# %%
#
# What are the backgrounds?
#
df[ (df["SampleName"].isnull()) ]
# Out:
#                  SampleName  SampleConcentration BufferContainer BufferName  \
# SampleChangerPos
# 1                       NaN                  NaN             NaN        NaN
# 2                       NaN                  NaN            Cell        NaN
# 3                       NaN                  NaN            Cell    PEG 400
# 7                       NaN                  NaN            Cell    PEG 400
#
#                   BufferPercentageD2O          Notes
# SampleChangerPos
# 1                                 NaN        Nothing
# 2                                 NaN  Just the cell
# 3                                30.0     Background
# 7                                60.0     Background
